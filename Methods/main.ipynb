# %%
from main import *
from particular_date_methods import * 
from particular_coordinates_methods import * 
from particular_country_methods import * 

data = import_data('../Data/input_data/ufo_sighting_data.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3214: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
ufo = get_copy(data)

# %% [markdown]
# ## Instrucciones
# Querida jugadora o querido jugador:
# A continuación se realizan una serie de procesos para generar datos y dejarlos tan limpitos que huelan incluso mejor que la colonia Nenuco:

# %%
columns_to_clean = ['state/province', 'country', 'UFO_shape','description']

# %%
ufo2 = drop_na_values_in_more_cols(ufo,columns_to_clean)

# %% [markdown]
# ## Generación de nuevos campos para el estudio:
# * Obtenemos las fechas, las horas y los meses a partir de `Date_time`
# * Tratamos las coordenadas
# * Obtenemos frecuencias de meses y años

# %%
ufo2 = get_cleaned_date_and_time(ufo2)

# %%
ufo2 = get_cleaned_coordinates(ufo2)

# %%
annual_freq2 = get_frequencies(ufo2, 'years')
monthly_freq2 = get_frequencies(ufo2, 'months')

# %% [markdown]
# Una vez que empezamos a considerar que los datos pueden ser accesibles, decidimos guardarlos:

# %%
export_data(ufo2, '../Data/output_data/clean_ufo_data.csv')

# %% [markdown]
# Vamos a realizar una pequeña muestra de gráficos que puedes utilizar

# %%
get_scatter(annual_freq2.keys(), annual_freq2.values(), (15)**2, 'cyan', 0.3)

# %%
get_boxplot(ufo2, 'months')

# %%
get_line(list(annual_freq2.keys()), list(annual_freq2.values()), 'cyan')

# %%
get_boxplot(ufo2, 'years')

# %%
get_boxplot(ufo2, ['latitude','longitude'])

# %%
get_distplot(ufo2, 'latitude', True)

# %%
get_violinplot(ufo2, 'years')

# %%
get_bar(ufo2, 'UFO_shape')

# %%
get_horizontal_bar(ufo2, 'UFO_shape')

# %%
get_bar(ufo2, 'country')

# %%
get_hist(ufo2, 'years')

# %%
get_scatter_matrix(ufo2)

# %% [markdown]
# Así que, ahora te toca a ti:
# * Ejecuta las siguientes líneas
# * Investiga qué métodos existen para plotear [aquí](https://github.com/ElenaCerezoSwing/visualizing-real-world-data-project/blob/master/Methods/plot.py)
# * Juega :)

# %%
clean_data = import_data('../Data/output_data/clean_ufo_data.csv')

# %% [markdown]
# Ahora puedes sacar la información por países, para ello utiliza los siguientes métodos y guardalos en una variable:
# * get_au_data(clean_data)
# * get_us_data(clean_data)
# * get_ca_data(clean_data)
# * get_gb_data(clean_data)
